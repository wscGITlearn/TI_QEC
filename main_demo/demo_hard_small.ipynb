# %%
# %run qsu.ipynb  # color-printing functions
import numpy as np
from qecsim import paulitools as pt
from qecsim.models.generic import DepolarizingErrorModel, BitFlipErrorModel, PhaseFlipErrorModel
from qecsim.models.planar import PlanarCode, PlanarMWPMDecoder, PlanarMPSDecoder
from ti_decoder import ti_calc
from gen_hard_synd import gen_hard_synd

# initialise models
d = 11
my_code = PlanarCode(d, d)
my_error_model = PhaseFlipErrorModel()
my_decoder = PlanarMWPMDecoder()
# print models
print(my_code)
print(my_error_model)
print(my_decoder)
# Out:
# PlanarCode(11, 11)
# PhaseFlipErrorModel()
# PlanarMWPMDecoder()

# %%
# set physical error probability to 10%
error_probability = 0.1

synd_lst, err_lst = gen_hard_synd(d=d, error_probability=error_probability, num_samples=1, seed=1)

error = err_lst[0]
qsu.print_pauli('error:\n{}'.format(my_code.new_pauli(error)))
# Out:
# <div class="highlight"><pre style="line-height:1!important; font-family: 'Courier New', monospace;">error:
# ·─┬─·─┬─·─┬─·─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·─┬─·─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   <span style="color:blue; font-weight:bold">Z</span>   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·
#   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   <span style="color:blue; font-weight:bold">Z</span>   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>
# ·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·</pre></div>

# %%
# syndrome: stabilizers that do not commute with the error
syndrome = pt.bsp(error, my_code.stabilizers.T)
qsu.print_pauli('syndrome:\n{}'.format(my_code.ascii_art(syndrome)))
# Out:
# <div class="highlight"><pre style="line-height:1!important; font-family: 'Courier New', monospace;">syndrome:
# ──┬───┬───┬───┬───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───┬───┬───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>──
#   │   │   │   │   │   │   │   │   │   │
# ──┼───<span style="color:red; font-weight:bold">X</span>───┼───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>──
#   │   │   │   │   │   │   │   │   │   │
# ──<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───┼───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───┼───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>──
#   │   │   │   │   │   │   │   │   │   │
# ──┼───<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───┼───┼───┼───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──┼───┼───┼───┼───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>──
#   │   │   │   │   │   │   │   │   │   │
# ──<span style="color:red; font-weight:bold">X</span>───┼───┼───┼───┼───┼───┼───<span style="color:red; font-weight:bold">X</span>───<span style="color:red; font-weight:bold">X</span>───┼──
#   │   │   │   │   │   │   │   │   │   │
# ──┴───┴───┴───┴───┴───┴───┴───┴───┴───<span style="color:red; font-weight:bold">X</span>──</pre></div>

# %% [markdown]
# Please add the following code to PlanarMPSDecoder class
# ```python
# def calc_coset_probabilities(self, code, syndrome,
#             error_model=DepolarizingErrorModel(),  # noqa: B008
#             error_probability=0.1, **kwargs):
#     """
#     See :meth:`qecsim.model.Decoder.decode`
#
#     Note: The optional keyword parameters ``error_model`` and ``error_probability`` are used to determine the prior
#     probability distribution for use in the decoding algorithm. Any provided error model must implement
#     :meth:`~qecsim.model.ErrorModel.probability_distribution`.
#
#     :param code: Planar code.
#     :type code: PlanarCode
#     :param syndrome: Syndrome as binary vector.
#     :type syndrome: numpy.array (1d)
#     :param error_model: Error model. (default=DepolarizingErrorModel())
#     :type error_model: ErrorModel
#     :param error_probability: Overall probability of an error on a single qubit. (default=0.1)
#     :type error_probability: float
#     :return: Recovery operation as binary symplectic vector.
#     :rtype: numpy.array (1d)
#     """
#     # any recovery
#     any_recovery = self.sample_recovery(code, syndrome)
#     # probability distribution
#     prob_dist = error_model.probability_distribution(error_probability)
#     # coset probabilities, recovery operations
#     coset_ps, recoveries = self._coset_probabilities(prob_dist, any_recovery)
#
#     return coset_ps, recoveries
# ```

# %%
# from mps decoder
my_mps_decoder = PlanarMPSDecoder(chi=6)
coset_ps, recoveries = my_mps_decoder.calc_coset_probabilities(
    my_code,
    syndrome,
    error_model=my_error_model,
    error_probability=error_probability)

print('total prob of each coset', coset_ps)
print('Only the first and last are non-zero because only Z errors.')
print('The log of their ratio is:',
      np.log(float(coset_ps[3]) / float(coset_ps[0])))
# Out:
# total prob of each coset (mpf('1.0854150609680467e-28'), mpf('0.0'), mpf('0.0'), mpf('5.5498607152402832e-29'))
# Only the first and last are non-zero because only Z errors.
# The log of their ratio is: -0.6707747204155996

# %%
recovery = recoveries[0].to_bsf()
qsu.print_pauli('recovery:\n{}'.format(my_code.new_pauli(recovery)))
# Out:
# <div class="highlight"><pre style="line-height:1!important; font-family: 'Courier New', monospace;">recovery:
# <span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─<span style="color:blue; font-weight:bold">Z</span></pre></div>

# %%
# couriosity:recovery ^ error
qsu.print_pauli('recovery ^ error:\n{}'.format(my_code.new_pauli(recovery ^ error)))
# Out:
# <div class="highlight"><pre style="line-height:1!important; font-family: 'Courier New', monospace;">recovery ^ error:
# <span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   <span style="color:blue; font-weight:bold">Z</span>   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# ·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   <span style="color:blue; font-weight:bold">Z</span>   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>
# ·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─·─┴─<span style="color:blue; font-weight:bold">Z</span></pre></div>

# %%
ti_calc(recovery,
           error_probability=error_probability,
           d=d,
           num_int_steps=201)
# Out:
# l = 0.00, energy derivative = -19.6440
# l = 0.01, energy derivative = -20.1280
# l = 0.01, energy derivative = -20.3560
# l = 0.01, energy derivative = -20.2440
# l = 0.02, energy derivative = -19.8440
# l = 0.03, energy derivative = -20.0720
# l = 0.03, energy derivative = -20.9160
# l = 0.04, energy derivative = -19.6280
# l = 0.04, energy derivative = -19.9840
# l = 0.04, energy derivative = -19.9960
# l = 0.05, energy derivative = -19.8640
# l = 0.06, energy derivative = -19.9640
# l = 0.06, energy derivative = -19.8040
# l = 0.07, energy derivative = -19.1080
# l = 0.07, energy derivative = -18.6960
# l = 0.07, energy derivative = -19.3960
# l = 0.08, energy derivative = -18.8840
# l = 0.09, energy derivative = -18.9360
# l = 0.09, energy derivative = -18.8720
# l = 0.10, energy derivative = -19.2800
# l = 0.10, energy derivative = -19.0360
# l = 0.10, energy derivative = -18.3880
# l = 0.11, energy derivative = -18.4080
# l = 0.12, energy derivative = -18.7760
# l = 0.12, energy derivative = -18.9880
# l = 0.12, energy derivative = -18.5640
# l = 0.13, energy derivative = -17.6280
# l = 0.14, energy derivative = -19.4880
# l = 0.14, energy derivative = -19.3040
# l = 0.14, energy derivative = -18.3960
# l = 0.15, energy derivative = -17.4080
# l = 0.15, energy derivative = -19.0360
# l = 0.16, energy derivative = -17.3680
# l = 0.17, energy derivative = -18.5880
# l = 0.17, energy derivative = -16.3120
# l = 0.18, energy derivative = -16.5280
# l = 0.18, energy derivative = -17.5840
# l = 0.18, energy derivative = -16.6760
# l = 0.19, energy derivative = -15.5920
# l = 0.20, energy derivative = -16.8280
# l = 0.20, energy derivative = -16.6960
# l = 0.21, energy derivative = -17.1280
# l = 0.21, energy derivative = -17.5160
# l = 0.21, energy derivative = -15.6600
# l = 0.22, energy derivative = -16.5240
# l = 0.23, energy derivative = -14.8920
# l = 0.23, energy derivative = -15.2120
# l = 0.24, energy derivative = -15.9080
# l = 0.24, energy derivative = -16.1800
# l = 0.24, energy derivative = -15.5800
# l = 0.25, energy derivative = -15.8960
# l = 0.26, energy derivative = -14.6600
# l = 0.26, energy derivative = -14.5280
# l = 0.27, energy derivative = -15.4200
# l = 0.27, energy derivative = -14.0680
# l = 0.28, energy derivative = -15.6040
# l = 0.28, energy derivative = -13.1080
# l = 0.29, energy derivative = -16.5800
# l = 0.29, energy derivative = -15.4880
# l = 0.29, energy derivative = -13.8960
# l = 0.30, energy derivative = -12.3160
# l = 0.30, energy derivative = -13.5440
# l = 0.31, energy derivative = -11.6840
# l = 0.32, energy derivative = -11.5480
# l = 0.32, energy derivative = -13.0640
# l = 0.33, energy derivative = -11.2960
# l = 0.33, energy derivative = -10.9600
# l = 0.34, energy derivative = -13.8000
# l = 0.34, energy derivative = -10.9920
# l = 0.35, energy derivative = -11.4080
# l = 0.35, energy derivative = -12.7960
# l = 0.35, energy derivative = -11.7560
# l = 0.36, energy derivative = -13.0280
# l = 0.36, energy derivative = -11.7120
# l = 0.37, energy derivative = -12.3760
# l = 0.38, energy derivative = -11.7040
# l = 0.38, energy derivative = -10.2520
# l = 0.39, energy derivative = -6.4920
# l = 0.39, energy derivative = -10.2840
# l = 0.40, energy derivative = -12.3160
# l = 0.40, energy derivative = -8.3200
# l = 0.41, energy derivative = -9.1720
# l = 0.41, energy derivative = -12.5440
# l = 0.42, energy derivative = -10.0240
# l = 0.42, energy derivative = -9.0440
# l = 0.42, energy derivative = -10.4400
# l = 0.43, energy derivative = -9.0200
# l = 0.43, energy derivative = -7.4640
# l = 0.44, energy derivative = -7.6480
# l = 0.45, energy derivative = -8.4320
# l = 0.45, energy derivative = -7.1640
# l = 0.46, energy derivative = -5.2200
# l = 0.46, energy derivative = -6.9120
# l = 0.47, energy derivative = -6.7040
# l = 0.47, energy derivative = -8.0680
# l = 0.48, energy derivative = -5.6040
# l = 0.48, energy derivative = -5.3160
# l = 0.48, energy derivative = -3.8200
# l = 0.49, energy derivative = 1.1200
# l = 0.49, energy derivative = -3.9920
# l = 0.50, energy derivative = -2.7760
# l = 0.51, energy derivative = -3.9080
# l = 0.51, energy derivative = -4.5600
# l = 0.52, energy derivative = -4.8240
# l = 0.52, energy derivative = -0.9960
# l = 0.53, energy derivative = -0.9800
# l = 0.53, energy derivative = -0.6000
# l = 0.54, energy derivative = 7.3160
# l = 0.54, energy derivative = -3.2040
# l = 0.55, energy derivative = -2.9640
# l = 0.55, energy derivative = -2.7320
# l = 0.56, energy derivative = 1.8560
# l = 0.56, energy derivative = -1.6320
# l = 0.57, energy derivative = 4.9200
# l = 0.57, energy derivative = 7.1560
# l = 0.58, energy derivative = -0.9320
# l = 0.58, energy derivative = 4.1040
# l = 0.58, energy derivative = 10.0440
# l = 0.59, energy derivative = 5.1840
# l = 0.59, energy derivative = 12.1800
# l = 0.60, energy derivative = 8.3840
# l = 0.60, energy derivative = 13.5120
# l = 0.61, energy derivative = 12.2800
# l = 0.61, energy derivative = 11.0680
# l = 0.62, energy derivative = 11.1960
# l = 0.62, energy derivative = 12.2480
# l = 0.63, energy derivative = 12.7720
# l = 0.64, energy derivative = 8.6080
# l = 0.64, energy derivative = 10.1880
# l = 0.65, energy derivative = 6.5840
# l = 0.65, energy derivative = 11.3080
# l = 0.66, energy derivative = 13.7600
# l = 0.66, energy derivative = 13.3520
# l = 0.67, energy derivative = 15.7600
# l = 0.67, energy derivative = 10.5320
# l = 0.68, energy derivative = 14.7600
# l = 0.68, energy derivative = 11.2840
# l = 0.69, energy derivative = 10.8680
# l = 0.69, energy derivative = 15.0080
# l = 0.70, energy derivative = 11.1320
# l = 0.70, energy derivative = 12.9040
# l = 0.70, energy derivative = 12.5720
# l = 0.71, energy derivative = 13.6080
# l = 0.71, energy derivative = 13.8680
# l = 0.72, energy derivative = 16.1960
# l = 0.72, energy derivative = 12.9120
# l = 0.73, energy derivative = 15.0280
# l = 0.73, energy derivative = 16.3080
# l = 0.74, energy derivative = 15.1840
# l = 0.74, energy derivative = 16.3560
# l = 0.75, energy derivative = 15.0280
# l = 0.76, energy derivative = 16.8040
# l = 0.76, energy derivative = 17.3440
# l = 0.77, energy derivative = 18.1320
# l = 0.77, energy derivative = 16.7040
# l = 0.78, energy derivative = 18.5120
# l = 0.78, energy derivative = 16.9240
# l = 0.79, energy derivative = 16.1200
# l = 0.79, energy derivative = 18.6920
# l = 0.80, energy derivative = 18.0560
# l = 0.80, energy derivative = 17.6840
# l = 0.81, energy derivative = 17.1960
# l = 0.81, energy derivative = 17.4120
# l = 0.82, energy derivative = 17.5000
# l = 0.82, energy derivative = 15.9600
# l = 0.83, energy derivative = 18.6200
# l = 0.83, energy derivative = 16.0840
# l = 0.83, energy derivative = 18.1760
# l = 0.84, energy derivative = 18.7080
# l = 0.84, energy derivative = 19.2680
# l = 0.85, energy derivative = 18.8600
# l = 0.85, energy derivative = 19.0280
# l = 0.86, energy derivative = 19.1800
# l = 0.86, energy derivative = 18.8920
# l = 0.87, energy derivative = 18.9720
# l = 0.88, energy derivative = 18.7080
# l = 0.88, energy derivative = 18.8680
# l = 0.89, energy derivative = 18.3440
# l = 0.89, energy derivative = 19.2200
# l = 0.90, energy derivative = 19.1760
# l = 0.90, energy derivative = 19.1960
# l = 0.91, energy derivative = 18.9440
# l = 0.91, energy derivative = 18.4840
# l = 0.92, energy derivative = 19.7920
# l = 0.92, energy derivative = 20.6200
# l = 0.93, energy derivative = 20.2760
# l = 0.93, energy derivative = 20.4480
# l = 0.94, energy derivative = 19.3520
# l = 0.94, energy derivative = 19.5960
# l = 0.95, energy derivative = 19.6720
# l = 0.95, energy derivative = 19.8440
# l = 0.96, energy derivative = 20.2880
# l = 0.96, energy derivative = 19.7800
# l = 0.96, energy derivative = 19.8680
# l = 0.97, energy derivative = 20.0000
# l = 0.97, energy derivative = 19.9720
# l = 0.98, energy derivative = 19.9600
# l = 0.98, energy derivative = 19.8720
# l = 0.99, energy derivative = 20.2320
# l = 0.99, energy derivative = 20.6400
# l = 1.00, energy derivative = 20.3240
# -0.45173188275543336

# %% [markdown]
# ## Try starting configuration from MWPM

# %%
mwpm = PlanarMWPMDecoder()
mwpm_recovery = mwpm.decode(my_code, syndrome)
qsu.print_pauli('recovery:\n{}'.format(my_code.new_pauli(mwpm_recovery)))
# Out:
# <div class="highlight"><pre style="line-height:1!important;">recovery:
# ·─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·─┬─<span style="color:blue; font-weight:bold">Z</span>─┬─·─┬─·─┬─·─┬─·─┬─·─┬─·
#   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·
#   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>
#   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·
#   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   ·   ·   ·   ·
# ·─┼─·─┼─·─┼─·─┼─<span style="color:blue; font-weight:bold">Z</span>─┼─·─┼─·─┼─·─┼─·─┼─·─┼─·
#   ·   ·   ·   ·   ·   ·   <span style="color:blue; font-weight:bold">Z</span>   ·   ·   ·
# <span style="color:blue; font-weight:bold">Z</span>─┴─<span style="color:blue; font-weight:bold">Z</span>─┴─·─┴─<span style="color:blue; font-weight:bold">Z</span>─┴─·─┴─<span style="color:blue; font-weight:bold">Z</span>─┴─·─┴─<span style="color:blue; font-weight:bold">Z</span>─┴─·─┴─·─┴─·</pre></div>

# %%
ti_calc(mwpm_recovery,
           error_probability=error_probability,
           d=d,
           num_int_steps=201)
# Out:
# l = 0.00, energy derivative = -19.9720
# l = 0.01, energy derivative = -20.1600
# l = 0.01, energy derivative = -20.3000
# l = 0.01, energy derivative = -20.3080
# l = 0.02, energy derivative = -20.1280
# l = 0.03, energy derivative = -20.2200
# l = 0.03, energy derivative = -20.6240
# l = 0.04, energy derivative = -19.8000
# l = 0.04, energy derivative = -20.1440
# l = 0.04, energy derivative = -20.3080
# l = 0.05, energy derivative = -20.1200
# l = 0.06, energy derivative = -19.9440
# l = 0.06, energy derivative = -20.4280
# l = 0.07, energy derivative = -19.8640
# l = 0.07, energy derivative = -19.5560
# l = 0.07, energy derivative = -18.9360
# l = 0.08, energy derivative = -19.6600
# l = 0.09, energy derivative = -19.3880
# l = 0.09, energy derivative = -19.2880
# l = 0.10, energy derivative = -19.1840
# l = 0.10, energy derivative = -19.2360
# l = 0.10, energy derivative = -18.6960
# l = 0.11, energy derivative = -19.1640
# l = 0.12, energy derivative = -19.5320
# l = 0.12, energy derivative = -19.6560
# l = 0.12, energy derivative = -19.3960
# l = 0.13, energy derivative = -18.6800
# l = 0.14, energy derivative = -18.4160
# l = 0.14, energy derivative = -19.4920
# l = 0.14, energy derivative = -18.8480
# l = 0.15, energy derivative = -18.7720
# l = 0.15, energy derivative = -18.1160
# l = 0.16, energy derivative = -18.4320
# l = 0.17, energy derivative = -18.9720
# l = 0.17, energy derivative = -19.3240
# l = 0.18, energy derivative = -19.1120
# l = 0.18, energy derivative = -19.0120
# l = 0.18, energy derivative = -17.4800
# l = 0.19, energy derivative = -18.4720
# l = 0.20, energy derivative = -15.8000
# l = 0.20, energy derivative = -16.9320
# l = 0.21, energy derivative = -15.8760
# l = 0.21, energy derivative = -15.7320
# l = 0.21, energy derivative = -18.5440
# l = 0.22, energy derivative = -17.7400
# l = 0.23, energy derivative = -18.3560
# l = 0.23, energy derivative = -15.0720
# l = 0.24, energy derivative = -18.1400
# l = 0.24, energy derivative = -17.4760
# l = 0.24, energy derivative = -14.0440
# l = 0.25, energy derivative = -15.4720
# l = 0.26, energy derivative = -15.3720
# l = 0.26, energy derivative = -12.1320
# l = 0.27, energy derivative = -13.8080
# l = 0.27, energy derivative = -14.8320
# l = 0.28, energy derivative = -13.4640
# l = 0.28, energy derivative = -13.7600
# l = 0.29, energy derivative = -16.5760
# l = 0.29, energy derivative = -14.5960
# l = 0.29, energy derivative = -15.5280
# l = 0.30, energy derivative = -14.1560
# l = 0.30, energy derivative = -10.5600
# l = 0.31, energy derivative = -11.9600
# l = 0.32, energy derivative = -11.2040
# l = 0.32, energy derivative = -16.6320
# l = 0.33, energy derivative = -12.7320
# l = 0.33, energy derivative = -16.3320
# l = 0.34, energy derivative = -15.1600
# l = 0.34, energy derivative = -9.0600
# l = 0.35, energy derivative = -10.9920
# l = 0.35, energy derivative = -14.8240
# l = 0.35, energy derivative = -13.9200
# l = 0.36, energy derivative = -9.8760
# l = 0.36, energy derivative = -14.7360
# l = 0.37, energy derivative = -12.1040
# l = 0.38, energy derivative = -14.4520
# l = 0.38, energy derivative = -11.8160
# l = 0.39, energy derivative = -10.1400
# l = 0.39, energy derivative = -8.3040
# l = 0.40, energy derivative = -10.1920
# l = 0.40, energy derivative = -10.0000
# l = 0.41, energy derivative = -12.8200
# l = 0.41, energy derivative = -11.2040
# l = 0.42, energy derivative = -9.8080
# l = 0.42, energy derivative = -10.3000
# l = 0.42, energy derivative = -2.8440
# l = 0.43, energy derivative = -4.8520
# l = 0.43, energy derivative = -0.4560
# l = 0.44, energy derivative = -10.2080
# l = 0.45, energy derivative = -2.7360
# l = 0.45, energy derivative = -4.4200
# l = 0.46, energy derivative = -6.6520
# l = 0.46, energy derivative = 4.0040
# l = 0.47, energy derivative = -0.1760
# l = 0.47, energy derivative = 2.4560
# l = 0.48, energy derivative = -3.3720
# l = 0.48, energy derivative = -9.1240
# l = 0.48, energy derivative = 5.1640
# l = 0.49, energy derivative = 7.3600
# l = 0.49, energy derivative = 0.9000
# l = 0.50, energy derivative = 2.1440
# l = 0.51, energy derivative = 2.1200
# l = 0.51, energy derivative = 5.7200
# l = 0.52, energy derivative = 6.4240
# l = 0.52, energy derivative = 7.5840
# l = 0.53, energy derivative = 6.0440
# l = 0.53, energy derivative = 4.4680
# l = 0.54, energy derivative = -4.1960
# l = 0.54, energy derivative = 7.6360
# l = 0.55, energy derivative = 6.9440
# l = 0.55, energy derivative = 8.2720
# l = 0.56, energy derivative = 5.5480
# l = 0.56, energy derivative = 6.2720
# l = 0.57, energy derivative = 8.0560
# l = 0.57, energy derivative = 8.5360
# l = 0.58, energy derivative = 8.4800
# l = 0.58, energy derivative = 8.1080
# l = 0.58, energy derivative = 4.4680
# l = 0.59, energy derivative = 9.2400
# l = 0.59, energy derivative = 7.8920
# l = 0.60, energy derivative = 8.3720
# l = 0.60, energy derivative = 11.5520
# l = 0.61, energy derivative = 9.6720
# l = 0.61, energy derivative = 10.5640
# l = 0.62, energy derivative = 10.1000
# l = 0.62, energy derivative = 10.1520
# l = 0.63, energy derivative = 10.8040
# l = 0.64, energy derivative = 10.2080
# l = 0.64, energy derivative = 10.0480
# l = 0.65, energy derivative = 10.0120
# l = 0.65, energy derivative = 12.6240
# l = 0.66, energy derivative = 12.7240
# l = 0.66, energy derivative = 13.3680
# l = 0.67, energy derivative = 13.9880
# l = 0.67, energy derivative = 15.5040
# l = 0.68, energy derivative = 12.6640
# l = 0.68, energy derivative = 14.2400
# l = 0.69, energy derivative = 12.9760
# l = 0.69, energy derivative = 12.8400
# l = 0.70, energy derivative = 12.0200
# l = 0.70, energy derivative = 13.2040
# l = 0.70, energy derivative = 14.0600
# l = 0.71, energy derivative = 14.0840
# l = 0.71, energy derivative = 13.1200
# l = 0.72, energy derivative = 14.4920
# l = 0.72, energy derivative = 14.0640
# l = 0.73, energy derivative = 14.8480
# l = 0.73, energy derivative = 15.1360
# l = 0.74, energy derivative = 16.5080
# l = 0.74, energy derivative = 14.5840
# l = 0.75, energy derivative = 13.8320
# l = 0.76, energy derivative = 16.2560
# l = 0.76, energy derivative = 14.7800
# l = 0.77, energy derivative = 15.5160
# l = 0.77, energy derivative = 16.5400
# l = 0.78, energy derivative = 15.5600
# l = 0.78, energy derivative = 15.9000
# l = 0.79, energy derivative = 15.6480
# l = 0.79, energy derivative = 17.1000
# l = 0.80, energy derivative = 15.5120
# l = 0.80, energy derivative = 17.1760
# l = 0.81, energy derivative = 18.8760
# l = 0.81, energy derivative = 16.7400
# l = 0.82, energy derivative = 17.7040
# l = 0.82, energy derivative = 16.9760
# l = 0.83, energy derivative = 16.6600
# l = 0.83, energy derivative = 17.4080
# l = 0.83, energy derivative = 18.0520
# l = 0.84, energy derivative = 18.1360
# l = 0.84, energy derivative = 17.6960
# l = 0.85, energy derivative = 18.4760
# l = 0.85, energy derivative = 17.8680
# l = 0.86, energy derivative = 17.6960
# l = 0.86, energy derivative = 17.0560
# l = 0.87, energy derivative = 19.0280
# l = 0.88, energy derivative = 19.1240
# l = 0.88, energy derivative = 17.6560
# l = 0.89, energy derivative = 18.6880
# l = 0.89, energy derivative = 18.1720
# l = 0.90, energy derivative = 18.7120
# l = 0.90, energy derivative = 18.7320
# l = 0.91, energy derivative = 19.5360
# l = 0.91, energy derivative = 19.4520
# l = 0.92, energy derivative = 18.6600
# l = 0.92, energy derivative = 19.1400
# l = 0.93, energy derivative = 19.5160
# l = 0.93, energy derivative = 19.8320
# l = 0.94, energy derivative = 19.5440
# l = 0.94, energy derivative = 18.9920
# l = 0.95, energy derivative = 19.5680
# l = 0.95, energy derivative = 19.7600
# l = 0.96, energy derivative = 20.1240
# l = 0.96, energy derivative = 19.7240
# l = 0.96, energy derivative = 19.6760
# l = 0.97, energy derivative = 19.6400
# l = 0.97, energy derivative = 19.7800
# l = 0.98, energy derivative = 20.5080
# l = 0.98, energy derivative = 19.7520
# l = 0.99, energy derivative = 19.5640
# l = 0.99, energy derivative = 19.8120
# l = 1.00, energy derivative = 20.5360
# 0.05494154589896081
